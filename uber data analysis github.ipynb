# %%
# Reading the image from a file
img = mpimg.imread('/Users/vishal/Desktop/Bootcamp.png')

# Displaying the image
plt.figure(dpi=300)
plt.imshow(img)
plt.axis('off')  # Hide the axis
plt.show()

# %% [markdown]
# # Uber Data Analysis

# %%
import os
os.getcwd()
# Out:
# '/Users/vishal'

# %% [markdown]
# # Importing the necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # Loading the dataset

# %%
df = pd.read_csv('/Users/vishal/Desktop/uber_data.csv')

# %% [markdown]
# # Basic Exploration

# %% [markdown]
# ### 1-	Display the top 5 rows.

# %%
df.head()
# Out:
#        pickup_dt    borough  pickups  spd   vsb  temp  dewp     slp  pcp01  \
# 0  1/1/2015 1:00      Bronx    152.0  5.0  10.0  30.0   7.0  1023.5    0.0
# 1  1/1/2015 1:00   Brooklyn   1519.0  5.0  10.0   NaN   7.0  1023.5    0.0
# 2  1/1/2015 1:00        EWR      0.0  5.0  10.0  30.0   7.0  1023.5    0.0
# 3  1/1/2015 1:00  Manhattan   5258.0  5.0  10.0  30.0   7.0  1023.5    0.0
# 4  1/1/2015 1:00     Queens    405.0  5.0  10.0  30.0   7.0  1023.5    0.0
#
#    pcp06  pcp24   sd hday
# 0    0.0    0.0  0.0    Y
# 1    0.0    0.0  0.0    ?
# 2    0.0    0.0  0.0    Y
# 3    0.0    0.0  0.0    Y
# 4    0.0    0.0  0.0    Y

# %% [markdown]
# Obervation :- on column 'temp' and 'hday' there is missing values on 2nd row Brooklyn temp = nan and hday = wrong entry(?)

# %%
# Reading the image from a file
img = mpimg.imread('/Users/vishal/Desktop/screenshots/Screenshot 2024-06-19 at 11.27.49.png')

# Displaying the image
plt.figure(dpi=300)
plt.imshow(img)
plt.axis('off')  # Hide the axis
plt.show()

# %%
df[df['hday']=='?']
# Out:
#           pickup_dt   borough  pickups  spd   vsb  temp  dewp     slp  pcp01  \
# 1     1/1/2015 1:00  Brooklyn   1519.0  5.0  10.0   NaN   7.0  1023.5    0.0
# 123  1/1/2015 19:00    Queens    238.0  7.0  10.0  37.0   7.0  1016.2    0.0
#
#      pcp06  pcp24   sd hday
# 1      0.0    0.0  0.0    ?
# 123    0.0    0.0  0.0    ?

# %%
df["hday"]=df["hday"].replace('?', np.nan)

# %%
df[df['hday']=='?']
# Out:
# Empty DataFrame
# Columns: [pickup_dt, borough, pickups, spd, vsb, temp, dewp, slp, pcp01, pcp06, pcp24, sd, hday]
# Index: []

# %% [markdown]
# ### 2-	Display the last 5 rows

# %%
df.tail()
# Out:
#               pickup_dt        borough  pickups  spd   vsb  temp  dewp  \
# 29096  30-06-2015 23:00            EWR      0.0  7.0  10.0  75.0  65.0
# 29097  30-06-2015 23:00      Manhattan   3828.0  7.0  10.0  75.0  65.0
# 29098  30-06-2015 23:00         Queens    580.0  7.0  10.0  75.0  65.0
# 29099  30-06-2015 23:00  Staten Island      0.0  7.0  10.0  75.0  65.0
# 29100  30-06-2015 23:00            NaN      3.0  7.0  10.0  75.0  65.0
#
#           slp  pcp01  pcp06  pcp24   sd hday
# 29096  1011.8    0.0    0.0    0.0  0.0    N
# 29097  1011.8    0.0    0.0    0.0  0.0    N
# 29098  1011.8    0.0    0.0    0.0  0.0    N
# 29099  1011.8    0.0    0.0    0.0  0.0    N
# 29100  1011.8    0.0    0.0    0.0  0.0    N

# %%
# Reading the image from a file
img = mpimg.imread('/Users/vishal/Desktop/screenshots/Screenshot 2024-06-19 at 11.29.27.png')

# Displaying the image
plt.figure(dpi=300)
plt.imshow(img)
plt.axis('off')  # Hide the axis
plt.show()

# %% [markdown]
# Obervation :- In column 'borough' and row 29100 value = NaN

# %% [markdown]
# ### 3- Check the shape of dataset.

# %%
df.shape
# Out:
# (29101, 13)

# %% [markdown]
#  Observation:- number of Rows = 29101 and number of coloumns = 15

# %% [markdown]
# ### 4- Check the info of dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11542 entries, 0 to 26161
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   pickup_dt   11542 non-null  datetime64[ns]
#  1   borough     10362 non-null  object
#  2   pickups     11540 non-null  float64
#  3   spd         11542 non-null  float64
#  4   vsb         11542 non-null  float64
#  5   temp        11255 non-null  float64
#  6   dewp        11542 non-null  float64
#  7   slp         11542 non-null  float64
#  8   pcp01       11542 non-null  float64
#  9   pcp06       11542 non-null  float64
#  10  pcp24       11542 non-null  float64
#  11  sd          11542 non-null  float64
#  12  hday        11540 non-null  object
#  13  weekday     11542 non-null  int32
#  14  is_weekend  11542 non-null  int64
# dtypes: datetime64[ns](1), float64(10), int32(1), int64(1), object(2)
# memory usage: 1.6+ MB

# %% [markdown]
# ### 5-	Check the datatypes of each feature.

# %%
df.dtypes
# Out:
# pickup_dt     datetime64[ns]
# borough               object
# pickups              float64
# spd                  float64
# vsb                  float64
# temp                 float64
# dewp                 float64
# slp                  float64
# pcp01                float64
# pcp06                float64
# pcp24                float64
# sd                   float64
# hday                  object
# weekday                int32
# is_weekend             int64
# dtype: object

# %% [markdown]
# Oberservation:- Weekday must be in object but here is in float

# %%
# Observation:- number of Rows = 29101 and number of coloumns = 15

# %%
df.dtypes
# Out:
# pickup_dt     datetime64[ns]
# borough               object
# pickups              float64
# spd                  float64
# vsb                  float64
# temp                 float64
# dewp                 float64
# slp                  float64
# pcp01                float64
# pcp06                float64
# pcp24                float64
# sd                   float64
# hday                  object
# weekday                int32
# is_weekend             int64
# dtype: object

# %% [markdown]
# ### 6-	Check the Statistical summary

# %%
df.describe().T
# Out:
#               count                           mean                  min  \
# pickup_dt     11542  2015-06-19 21:03:22.114018560  2015-01-01 01:00:00
# pickups     11540.0                     469.012998                  0.0
# spd         11542.0                       6.012221                  0.0
# vsb         11542.0                       8.583896                  0.3
# temp        11255.0                      46.537079                  0.0
# dewp        11542.0                      30.583345                -13.0
# slp         11542.0                    1107.281312                  1.0
# pcp01       11542.0                       0.003658                  0.0
# pcp06       11542.0                       0.026959                  0.0
# pcp24       11542.0                       0.097715                  0.0
# sd          11542.0                       3.497578                  0.0
# weekday     11542.0                       3.024606                  0.0
# is_weekend  11542.0                       0.277162                  0.0
#
#                             25%                  50%                  75%  \
# pickup_dt   2015-04-01 01:15:00  2015-07-01 02:00:00  2015-10-01 00:45:00
# pickups                     1.0                 50.0                429.0
# spd                         3.0                  6.0                  8.0
# vsb                         8.0                 10.0                 10.0
# temp                       31.0                 45.0                 61.0
# dewp                       16.0                 30.0                 47.0
# slp                      1014.9               1020.1               1023.8
# pcp01                       0.0                  0.0                  0.0
# pcp06                       0.0                  0.0                  0.0
# pcp24                       0.0                  0.0               0.0555
# sd                          0.0                  0.0                  8.0
# weekday                     1.0                  3.0                  5.0
# is_weekend                  0.0                  0.0                  1.0
#
#                             max          std
# pickup_dt   2015-12-06 23:00:00          NaN
# pickups                  6413.0   955.100153
# spd                        21.0      3.69717
# vsb                        10.0     2.496396
# temp                       89.0    18.536322
# dewp                       71.0    19.566648
# slp                   1015200.0  9440.067449
# pcp01                      0.15     0.014616
# pcp06                      1.21     0.086358
# pcp24                      1.89     0.222236
# sd                         19.0     5.316465
# weekday                     6.0     1.993817
# is_weekend                  1.0     0.447616

# %% [markdown]
# obervation dew point is -16

# %% [markdown]
# ### 7-	Check the null values

# %%
df.isnull().sum()
# Out:
# pickup_dt        0
# borough       1180
# pickups          2
# spd              0
# vsb              0
# temp           287
# dewp             0
# slp              0
# pcp01            0
# pcp06            0
# pcp24            0
# sd               0
# hday             2
# weekday          0
# is_weekend       0
# dtype: int64

# %% [markdown]
# Observation:- coloumn borough and temp having null values 1180 and 287

# %% [markdown]
# ### Replacing null values from

# %% [markdown]
# ### 8-	Check the duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 9-	Check the anomalies or wrong entries.

# %%
df[df['pickups'] < 0]
# Out:
# Empty DataFrame
# Columns: [pickup_dt, borough, pickups, spd, vsb, temp, dewp, slp, pcp01, pcp06, pcp24, sd, hday, weekday, is_weekend]
# Index: []

# %% [markdown]
# ### 10-	Check the outliers and their authenticity.

# %%
from scipy.stats import zscore
(zscore(df['pickups']) > 0).sum()
# Out:
# 0

# %% [markdown]
# ### 11-	Do the necessary data cleaning steps like dropping duplicates, unnecessary columns, null value imputation, outliers treatment etc.

# %%
uber_data_cleaned = df.dropna().drop_duplicates()
print("Shape after cleaning:\n", uber_data_cleaned.shape)
# Out:
# Shape after cleaning:
#  (25696, 13)

# %%
df['pickup_dt'] = pd.to_datetime(df['pickup_dt'], format='%m/%d/%Y %H:%M', errors='coerce')
df = df.dropna(subset=['pickup_dt'])

# %%
# Dropping duplicates
df= df.drop_duplicates()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.xticks(rotation = 45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=(10,6))
#       2 sns.boxplot(data=df)
#       3 plt.xticks(rotation = 45)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # 1. Pickup Analysis

# %% [markdown]
# ### 1.	What is the total number of Uber pickups across all boroughs?

# %%
total_pickups = df['pickups'].sum()
print("Total number of Uber pickups across all boroughs : ", total_pickups)
# Out:
# Total number of Uber pickups across all boroughs :  5412410.0

# %% [markdown]
# ### 2.	Which borough has the highest average number of hourly pickups?

# %%
highest_avg = df.groupby('borough')['pickups'].mean().idxmax()
print("Highest average is:-",highest_avg)
# Out:
# Highest average is:- Manhattan

# %% [markdown]
# ### 3.	How do the number of pickups vary across different hours of the day?

# %%
pickups_per_hour = df.groupby(['pickups'])['hday'].sum()
print("Number of pickups across different hours of the day:")
print(pickups_per_hour)
# Out:
# Number of pickups across different hours of the day:
# pickups
# 0.0       YYYYYYYYYYYYYYYYYYYYYYYYYYYNNNNNNNNNNNNNNNNNNN...
# 1.0       YYYYYYYYYYYYYYYYYNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...
# 2.0       YYYYYYNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...
# 3.0       YYYYNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...
# 4.0       YYNNNNNNNNNNNNNNNNNNNNNNNNNNNNYNNNNNNNNNNNNNNN...
#                                 ...
# 5857.0                                                    N
# 5976.0                                                    N
# 5984.0                                                    N
# 6067.0                                                    N
# 6413.0                                                    N
# Name: hday, Length: 2103, dtype: object

# %%
plt.figure(figsize=(10,3))
sns.scatterplot(data = df, x='pickups', y='hday');

# %% [markdown]
# ### 4.	Which day of the week has the highest number of pickups?

# %%
highest_pickups = df.groupby(df['pickup_dt'].dt.day_name())['pickups'].sum().idxmax()
print("Day of the week with the highest number of pickups:", highest_pickups)
# Out:
# Day of the week with the highest number of pickups: Friday

# %% [markdown]
# # 2. Weather Impact

# %% [markdown]
# ### 1. What is the correlation between temperature and the number of pickups?

# %%
correlation_temp_pickups = df['temp'].corr(df['pickups'])
print("Correlation between temperature and number of pickups:", correlation_temp_pickups)
# Out:
# Correlation between temperature and number of pickups: 0.05949598361045456

# %% [markdown]
# ### 2.	How does visibility impact the number of pickups?

# %%
number_of_pickups = df['vsb'].corr(df['pickups'])
print("Correlation between visibility and number of pickups:", number_of_pickups)
# Out:
# Correlation between visibility and number of pickups: -0.0066786975697342215

# %% [markdown]
# ### 3.	Is there a relationship between wind speed and the number of pickups?

# %%
correlation_spd_pickups = df['spd'].corr(df['pickups'])
print("Correlation between wind speed and number of pickups:", correlation_spd_pickups)
# Out:
# Correlation between wind speed and number of pickups: 0.013278201674501073

# %% [markdown]
# ### 4.	How does precipitation (1-hour, 6-hour, 24-hour) affect the number of pickups?

# %%
correlation_pcp01_pickups = df['pcp01'].corr(df['pickups'])
print("Correlation between 1-hour precipitation and number of pickups:", correlation_pcp01_pickups)
# Out:
# Correlation between 1-hour precipitation and number of pickups: -0.00796728467196359

# %% [markdown]
# # 3. Seasonal Trends

# %% [markdown]
# ### 1.	How do the number of pickups vary across different seasons (winter, spring, summer, fall)?

# %%
pickups_per_season = df.assign(season=df['pickup_dt'].dt.month.map(lambda x: 'Winter' if x in [12, 1, 2] else 'Spring' if x in [3, 4, 5] else 'Summer' if x in [6, 7, 8] else 'Fall')).groupby('season')['pickups'].sum()
print(pickups_per_season)
# Out:
# season
# Fall      1367015.0
# Spring    1301403.0
# Summer    1371609.0
# Winter    1372383.0
# Name: pickups, dtype: float64

# %% [markdown]
# ### 2.	What is the average number of pickups during holidays compared to non-holidays?

# %%
df.groupby('hday')['pickups'].mean()
# Out:
# hday
# N    468.243052
# Y    480.943307
# Name: pickups, dtype: float64

# %% [markdown]
# ### 3.	How does snow depth influence the number of pickups?

# %%
df.groupby('sd')['pickups'].mean()
# Out:
# sd
# 0.000000     481.326865
# 0.041667     106.263158
# 0.083333     165.421053
# 0.125000     230.809524
# 0.166667     319.500000
#                 ...
# 18.833333    227.428571
# 18.875000    188.666667
# 18.916667    149.666667
# 18.958333    122.714286
# 19.000000    147.428571
# Name: pickups, Length: 260, dtype: float64

# %% [markdown]
# # 4. Hourly Trends

# %% [markdown]
# ### 1.	What are the peak hours for Uber pickups in each borough?

# %%
df.groupby(['borough', df['pickup_dt'].dt.hour])['pickups'].sum().idxmax()
# Out:
# ('Manhattan', 19)

# %% [markdown]
# ### 2.	How do the number of pickups change during rush hours (e.g., 7-9 AM, 5-7 PM)?

# %%
rush_hours_pickups = df[df['pickup_dt'].dt.hour.isin([7, 8, 9, 17, 18, 19])].groupby(df['pickup_dt'].dt.hour)['pickups'].sum()
print(rush_hours_pickups)

# %% [markdown]
# ### 3.	What is the average number of pickups during late-night hours (e.g., 12 AM - 4 AM)?

# %%
late_night_avg_pickups = df[df['pickup_dt'].dt.hour.isin([0, 1, 2, 3, 4])]['pickups'].mean()
print(late_night_avg_pickups)

# %% [markdown]
# # 5. Borough Comparison

# %% [markdown]
# ### 1.	How do pickup trends differ between boroughs during different weather conditions?

# %%
pickup_trends_weather = df.groupby(['borough'])[['temp', 'vsb', 'pickups']].mean()
print(pickup_trends_weather)

# %% [markdown]
# ### 2.	Which borough shows the highest increase in pickups during holidays?

# %%
holiday_increase = df.groupby(['borough', 'hday'])['pickups'].mean().unstack().apply(lambda x: x['Y'] - x['N'], axis=1).idxmax()
print(holiday_increase)

# %% [markdown]
# ### 3.	How does the number of pickups compare between weekdays and weekends for each borough?

# %%
df['pickup_dt'] = pd.to_datetime(df['pickup_dt'], format='%m/%d/%Y %H:%M', errors='coerce')
df['weekday'] = df['pickup_dt'].dt.dayofweek
df['is_weekend'] = df['weekday'].apply(lambda x: 1 if x >= 5 else 0)
weekday_weekend_comparison = df.groupby(['borough', 'is_weekend'])['pickups'].mean()
print(weekday_weekend_comparison)

# %%
# Set the style of the visualization
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(12, 6))
sns.barplot(x='borough', y='num_pickups', hue='day_type', data=df, palette='viridis')

# Add titles and labels
plt.title('Number of Pickups: Weekdays vs Weekends for Each Borough')
plt.xlabel('Borough')
plt.ylabel('Number of Pickups')
plt.legend(title='Day Type')

# Show the plot
plt.show()

# %% [markdown]
# # 6. Weather Extremes

# %% [markdown]
# ### 1.	How do extreme weather conditions (e.g., very high or very low temperatures, heavy rainfall, snowstorms) affect the number of pickups?

# %% [markdown]
# ### 2.	What is the impact of visibility less than 1 mile on the number of pickups?

# %% [markdown]
# # 7. Data Correlations

# %% [markdown]
# ### 1.	Is there a correlation between sea level pressure and the number of pickups?

# %% [markdown]
# ### 2.	How do different weather variables (temperature, dew point, wind speed, visibility) collectively impact the number of pickups?

# %% [markdown]
# ### 3.	What is the relationship between holiday status and weather conditions on the number of pickups?

# %% [markdown]
# # 8. Growth Insights

# %% [markdown]
# ### 1.	Which weather conditions are most favorable for Uber pickups, and how can this information be used to optimize driver availability?

# %% [markdown]
# ### 2. Based on the data, what recommendations can be made to Uber to increase pickups during low-demand periods?
